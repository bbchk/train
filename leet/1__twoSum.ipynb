// %% [markdown]
// ![image.png](attachment:3bb4a24e-ec65-42d3-8220-98507469fd6a.png)
//
// ![image.png](attachment:a58ae2a8-42e7-45ba-bf4b-19c0716b631c.png)

// %%
// computational complexity efficient solution
function twoSum(nums, target) {
    const map = new Map();
    for(let i = 0; i < nums.length; i++){
        const complement = target - nums[i]
        
        if(map.has(complement)) {
            return [map.get(complement), i] 
        }
        
        map.set(nums[i], i)
    }
}

const nums = [3,2,4]
const target = 6
console.log(twoSum(nums, target))
// Out:
// [ 1, 2 ]

// %%
//space complexity efficient solution

// Variations:
// -- 1 -- maybe we could put -1 temprorarily on place of current elem and then use indexOf on array
// -- 2 -- two pointer approach


function twoSum(nums, target) {

    const sortedIndices = nums.map((value, index) => ({ value, index }))
                               .sort((a, b) => a.value - b.value);
    console.log(sortedIndices)
}

const nums = [3,2,4]
const target = 6
console.log(twoSum(nums, target))
// Out:
// [
//   { value: 2, index: 1 },
//   { value: 3, index: 0 },
//   { value: 4, index: 2 }
// ]
// undefined
