// %% [markdown]
// ![image.png](attachment:70f90c35-3d9d-405b-beb5-f7ca2432cf28.png)

// %% [markdown]
// top case is: a = 1 2 997
//
// low case is: a = 25 25
//
// ok, so what is brute force solution?
//
// traverse a to the 1000/3, b to 1000/2 and c to 1000 from 1000/2

// %%
const limit = 1000;

for (let a = 0; a < limit/3; a++){
for (let a = 0; a < limit/3; a++){
    
}    
}
