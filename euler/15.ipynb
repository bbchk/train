// %% [markdown]
// ![image.png](attachment:489989fd-9588-4afd-888d-5b25167f0e8b.png)

// %%
function factorial(n) {
    let res = 1;

    for (let i = 1; i <= n; i++) {
        res *= i;
    }

    return res;
}

function lattice(gridSize) {

    return factorial(gridSize * 2) / (factorial(gridSize) * factorial(gridSize));
}

console.log(lattice(20))
// Out:
// 137846528820
